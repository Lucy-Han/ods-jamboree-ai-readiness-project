# %% [markdown]
# # CCDI Hub DICOM Analysis
#
# This notebook extracts metadata from all DICOM files in the sample and assesses the 3 data quality measures: consistency, completeness, and outliers
#
# Author: Lucy Han, Booz Allen Hamilton

# %%
# install pydicom
# %pip install pydicom
# Out:
# Requirement already satisfied: pydicom in /opt/conda/lib/python3.11/site-packages (3.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import pydicom, pandas, and os
import pydicom
import pandas as pd
import os

# %%
# checking current path for Jupyter Notebook
current_path = os.getcwd()
print(current_path)
# Out:
# /sbgenomics/workspace

# %% [markdown]
# ## Get and sort MCI DICOM files

# %%
# set file paths
file_src = '/sbgenomics/project-files/Reference_Files/Filtered'

# %%
RMS_manifest_file = file_src + '/filtered_CCDI Hub_RMS Path DICOM Files Manifest_2025-09-18 21-24-21.csv'
MCI_manifest_file = file_src + '/filtered_CCDI Hub_MCI Path DICOM Files Manifest_2025-09-18 21-12-26.csv'

# %%
RMS_manifest_df = pd.read_csv(RMS_manifest_file)
MCI_manifest_df = pd.read_csv(MCI_manifest_file)

# %%
RMS_manifest_df.shape
# Out:
# (246, 9)

# %%
MCI_manifest_df.shape
# Out:
# (462, 10)

# %%
MCI_manifest_df.head(10)
# Out:
#                                   File Name      Data Category  \
# 0  0049cac2-5490-4212-8014-e6176d1f3ff1.dcm  Pathology Imaging
# 1  0049cac2-5490-4212-8014-e6176d1f3ff1.dcm  Pathology Imaging
# 2  0302064c-08a3-4134-b0a4-767b971bb761.dcm  Pathology Imaging
# 3  0302064c-08a3-4134-b0a4-767b971bb761.dcm  Pathology Imaging
# 4  03f7f0e3-c95f-4b88-b33c-0f5595343407.dcm  Pathology Imaging
# 5  03f7f0e3-c95f-4b88-b33c-0f5595343407.dcm  Pathology Imaging
# 6  04588d47-8c04-448d-8370-2761be9a1087.dcm  Pathology Imaging
# 7  04588d47-8c04-448d-8370-2761be9a1087.dcm  Pathology Imaging
# 8  0497ff2c-a847-4d04-8367-40f60bbb11a9.dcm  Pathology Imaging
# 9  0497ff2c-a847-4d04-8367-40f60bbb11a9.dcm  Pathology Imaging
#
#    File Description File Type  File Size File Access   Study ID  \
# 0               NaN     dicom  627.72 MB        Open  phs002790
# 1               NaN     dicom  627.72 MB        Open  phs002790
# 2               NaN     dicom  714.79 MB        Open  phs002790
# 3               NaN     dicom  714.79 MB        Open  phs002790
# 4               NaN     dicom  190.44 MB        Open  phs002790
# 5               NaN     dicom  190.44 MB        Open  phs002790
# 6               NaN     dicom  409.15 MB        Open  phs002790
# 7               NaN     dicom  409.15 MB        Open  phs002790
# 8               NaN     dicom    1.44 GB        Open  phs002790
# 9               NaN     dicom    1.44 GB        Open  phs002790
#
#   Participant ID Sample ID  Unnamed: 9
# 0         PBBWZZ    0DJM8P         NaN
# 1         PBBWZZ    0DJM98         NaN
# 2         PBCDDH    0DPBFU         NaN
# 3         PBCDDH    0DPBGV         NaN
# 4         PBBXEL    0DJM8R         NaN
# 5         PBBXEL    0DJM95         NaN
# 6         PBBSRF    0DFXFF         NaN
# 7         PBBSRF    0DFXH2         NaN
# 8         PBCKEL    0DUB86         NaN
# 9         PBCKEL    0DUB9K         NaN

# %%
dicomFileList = [] # initiate list to hold file directories

# %%
# local path to the file directory
# update the line below to match your directory
src = "/sbgenomics/project-files/MCI/MCI_Imaging"

# loop through all files in src directory
for root, dirs, files in os.walk(src):
    for file in files: 
        if file in list(MCI_manifest_df['File Name']): # check if .dcm is in the file name
            dicomFileList.append(os.path.join(root, file))

# %%
# number of files in the dicomFileList for the MCI study
len(dicomFileList)

# %%
# local path to the file directory
# update the line below to match your directory
src = "/sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging"

# loop through all files in src directory
for root, dirs, files in os.walk(src):
    for file in files: 
        if file in list(RMS_manifest_df['File Name']): # check if .dcm is in the file name
            dicomFileList.append(os.path.join(root, file))

# %%
# number of files in the dicomFileList for the MCI and the RMS studies
len(dicomFileList)
# Out:
# 399

# %%
dicomFileList = list(set(dicomFileList))

# %%
len(dicomFileList)
# Out:
# 399

# %% [markdown]
# # Completeness and Consistency dictionaries for DICOM headers

# %%
# import pydicom, os, counter, and math
import pydicom
import os
from collections import Counter
import math

# %%
def recurse(d, d_dict, elem_list, k="", first_file=False):
    # function to recursively extract data elements from the DICOM headers
    
    for elem in d:
        if elem.VR == 'SQ':
            if elem.keyword not in ['CodingSchemeIdentificationSequence',
                                    'Specimen Preparation Sequence', 
                                    'SpecimenDescriptionSequence',
                                    'DimensionOrganizationSequence',
                                   'DimensionIndexSequence']:
                for item in elem.value:
                    recurse(item, d_dict, elem_list, elem.keyword, first_file)
        else:
            if elem.keyword not in ["ICCProfile", ""]:
                dict_key = f"{k}:{elem.keyword}".lstrip(":")                
                if dict_key not in d_dict.keys():
                    if first_file:
                        d_dict[dict_key] = [] #initiate empty list
                    continue  
                d_dict[dict_key].append(elem.value) # add value to the list
                elem_list.append(dict_key)

# %%
def get_values_dict(file_list):
    # function that returns a dictionary of values from the dicom headers

    # file_list is an input list of the the files to extract data from

    field_dict = {} # initiate dictionary
    list_of_elements = []
    ds = pydicom.filereader.dcmread(file_list[0], stop_before_pixels=True) # read file
    recurse(ds, field_dict, list_of_elements, k="", first_file=True) #recurse

    file_counter = 0 # initate counter

    # loop through files
    for file in file_list:
        ds = pydicom.filereader.dcmread(file, stop_before_pixels=True) # read file

        # loop through headers
        list_of_elements = []
        recurse(ds, field_dict, elem_list=list_of_elements) # recurse

        elements_not_in_first = list(set(field_dict.keys()) - set(list_of_elements))
        for e in elements_not_in_first:
            field_dict[e].append('Not Present')
        
        file_counter+=1 # increase counter
        print(f"{file} processed. {file_counter} files have been read.")
    return field_dict

# %%
def get_completeness_consistency(values_dict):
    # function that returns a dictionary about the consistency of the data

    # values_dict is a dictionary of key (headers) and the values from the dicom headers

    consistency_dict = {} # initiate dictionary

    fields = values_dict.keys() # get keys

    # loop through keys
    for field in fields:
        try:
            set(values_dict[field]) # get unique set
            consistency_dict[field] = Counter(values_dict[field]) # count values per item in set
        except: # if data type that a set cannot be taken from
            consistency_dict[field] = values_dict[field] # add the values to the dictionary
    return consistency_dict

# %%
# #Example of reading a DICOM image and printing the metadata headers
ds = pydicom.filereader.dcmread("/sbgenomics/project-files/MCI/MCI_Imaging/815b7904-14f5-4007-9edf-3792185b6e18.dcm")
print(ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 224
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: VL Whole Slide Microscopy Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.5962.99.1.1907836886.1276421301.1719894788054.11.0
# (0002,0010) Transfer Syntax UID                 UI: JPEG Baseline (Process 1)
# (0002,0012) Implementation Class UID            UI: 1.3.6.1.4.1.5962.99.2
# (0002,0013) Implementation Version Name         SH: 'PIXELMEDJAVA001'
# (0002,0016) Source Application Entity Title     AE: 'OURAETITLE'
# -------------------------------------------------
# (0008,0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'VOLUME', 'NONE']
# (0008,0012) Instance Creation Date              DA: '20240702'
# (0008,0013) Instance Creation Time              TM: '043524.332'
# (0008,0014) Instance Creator UID                UI: 1.3.6.1.4.1.5962.99.3
# (0008,0016) SOP Class UID                       UI: VL Whole Slide Microscopy Image Storage
# (0008,0017) Acquisition UID                     UI: 1.3.6.1.4.1.5962.99.1.1907836886.1276421301.1719894788054.3.0
# (0008,0018) SOP Instance UID                    UI: 1.3.6.1.4.1.5962.99.1.1907836886.1276421301.1719894788054.11.0
# (0008,0019) Pyramid UID                         UI: 1.3.6.1.4.1.5962.99.1.1907836886.1276421301.1719894788054.2.0
# (0008,0020) Study Date                          DA: '20230428'
# (0008,0021) Series Date                         DA: '20230428'
# (0008,0022) Acquisition Date                    DA: '20230428'
# (0008,0023) Content Date                        DA: '20230428'
# (0008,002A) Acquisition DateTime                DT: '20230428123832'
# (0008,0030) Study Time                          TM: '123832'
# (0008,0031) Series Time                         TM: '123832'
# (0008,0032) Acquisition Time                    TM: '123832'
# (0008,0033) Content Time                        TM: '123832'
# (0008,0050) Accession Number                    SH: 'PBBZHP'
# (0008,0060) Modality                            CS: 'SM'
# (0008,0070) Manufacturer                        LO: 'Leica Biosystems'
# (0008,0090) Referring Physician's Name          PN: '^^^^'
# (0008,0110)  Coding Scheme Identification Sequence  3 item(s) ----
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,010C) Coding Scheme UID                   UI: DICOM Controlled Terminology
#    (0008,0112) Coding Scheme Registry              LO: 'HL7'
#    (0008,0115) Coding Scheme Name                  ST: 'DICOM Controlled Terminology'
#    ---------
#    (0008,0102) Coding Scheme Designator            SH: 'ICDO3'
#    (0008,010C) Coding Scheme UID                   UI: 2.16.840.1.113883.6.43.1
#    (0008,0112) Coding Scheme Registry              LO: 'HL7'
#    (0008,0115) Coding Scheme Name                  ST: 'ICD-O-3'
#    ---------
#    (0008,0102) Coding Scheme Designator            SH: 'SCT'
#    (0008,010C) Coding Scheme UID                   UI: 2.16.840.1.113883.6.96
#    (0008,0112) Coding Scheme Registry              LO: 'HL7'
#    (0008,0115) Coding Scheme Name                  ST: 'SNOMED CT using SNOMED-CT style values'
#    ---------
# (0008,0201) Timezone Offset From UTC            SH: '+0000'
# (0008,1030) Study Description                   LO: 'Histopathology'
# (0008,103E) Series Description                  LO: 'FFPE HE T'
# (0008,1084)  Admitting Diagnoses Code Sequence  1 item(s) ----
#    (0008,0100) Code Value                          SH: '8910/3'
#    (0008,0102) Coding Scheme Designator            SH: 'ICDO3'
#    (0008,0104) Code Meaning                        LO: 'Embryonal rhabdomyosarcoma, NOS'
#    ---------
# (0008,1090) Manufacturer's Model Name           LO: 'Aperio converted by com.pixelmed.convert.TIFFToDicom'
# (0008,9206) Volumetric Properties               CS: 'VOLUME'
# (0009,0010) Private Creator                     LO: 'PixelMed Publishing'
# (0009,1001) Private tag data                    UT: Array of 37 elements
# (0009,1002) Private tag data                    US: 0
# (0010,0010) Patient's Name                      PN: 'PBBZHP'
# (0010,0020) Patient ID                          LO: 'PBBZHP'
# (0010,0030) Patient's Birth Date                DA: ''
# (0010,0040) Patient's Sex                       CS: 'M'
# (0010,1010) Patient's Age                       AS: '040M'
# (0010,2160) Ethnic Group                        SH: 'Black'
# (0012,0010) Clinical Trial Sponsor Name         LO: 'National Cancer Institute (NCI) Childhood Cancer Data Initiative'
# (0012,0020) Clinical Trial Protocol ID          LO: 'phs002790'
# (0012,0021) Clinical Trial Protocol Name        LO: 'CCDI Molecular Characterization Initiative'
# (0012,0022) Issuer of Clinical Trial Protocol I LO: 'dbGaP'
# (0012,0023)  Other Clinical Trial Protocol IDs Sequence  1 item(s) ----
#    (0012,0020) Clinical Trial Protocol ID          LO: 'doi:10.5281/zenodo.11099087'
#    (0012,0022) Issuer of Clinical Trial Protocol I LO: 'DOI'
#    ---------
# (0012,0030) Clinical Trial Site ID              LO: ''
# (0012,0031) Clinical Trial Site Name            LO: ''
# (0012,0040) Clinical Trial Subject ID           LO: 'PBBZHP'
# (0012,0060) Clinical Trial Coordinating Center  LO: "Nationwide Children's Hospital"
# (0013,0010) Private Creator                     LO: 'CTP'
# (0013,1010) Private tag data                    LO: 'phs002790'
# (0018,1000) Device Serial Number                LO: 'SS12172'
# (0018,1020) Software Versions                   LO: ['v1.0.1', 'Sat May  4 08:37:59 EDT 2024']
# (0018,9004) Content Qualification               CS: 'RESEARCH'
# (0018,A001)  Contributing Equipment Sequence  1 item(s) ----
#    (0008,0070) Manufacturer                        LO: 'PixelMed'
#    (0008,0080) Institution Name                    LO: 'PixelMed'
#    (0008,0081) Institution Address                 ST: 'Bangor, PA'
#    (0008,1040) Institutional Department Name       LO: 'Software Development'
#    (0008,1090) Manufacturer's Model Name           LO: 'com.pixelmed.convert.TIFFToDicom'
#    (0018,1020) Software Versions                   LO: 'Vers. Sat May  4 08:37:59 EDT 2024'
#    (0018,A002) Contribution DateTime               DT: '20240702043524.839+0000'
#    (0018,A003) Contribution Description            ST: 'TIFF to DICOM conversion'
#    (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#       (0008,0100) Code Value                          SH: '109103'
#       (0008,0102) Coding Scheme Designator            SH: 'DCM'
#       (0008,0104) Code Meaning                        LO: 'Modifying Equipment'
#       ---------
#    ---------
# (0020,000D) Study Instance UID                  UI: 2.25.150412263020618428427983307175506491202
# (0020,000E) Series Instance UID                 UI: 1.3.6.1.4.1.5962.99.1.1907836886.1276421301.1719894788054.4.0
# (0020,0010) Study ID                            SH: 'PBBZHP'
# (0020,0011) Series Number                       IS: '1'
# (0020,0013) Instance Number                     IS: '1'
# (0020,0020) Patient Orientation                 CS: ''
# (0020,0052) Frame of Reference UID              UI: 1.3.6.1.4.1.5962.99.1.1907836886.1276421301.1719894788054.7.0
# (0020,1040) Position Reference Indicator        LO: 'UNKNOWN'
# (0020,4000) Image Comments                      LT: Array of 374 elements
# (0020,9221)  Dimension Organization Sequence  1 item(s) ----
#    (0020,9164) Dimension Organization UID          UI: 1.3.6.1.4.1.5962.99.1.1907836886.1276421301.1719894788054.16.0
#    ---------
# (0020,9222)  Dimension Index Sequence  2 item(s) ----
#    (0020,9164) Dimension Organization UID          UI: 1.3.6.1.4.1.5962.99.1.1907836886.1276421301.1719894788054.16.0
#    (0020,9165) Dimension Index Pointer             AT: (0048,021F)
#    (0020,9167) Functional Group Pointer            AT: (0048,021A)
#    (0020,9421) Dimension Description Label         LO: 'Row Position'
#    ---------
#    (0020,9164) Dimension Organization UID          UI: 1.3.6.1.4.1.5962.99.1.1907836886.1276421301.1719894788054.16.0
#    (0020,9165) Dimension Index Pointer             AT: (0048,021E)
#    (0020,9167) Functional Group Pointer            AT: (0048,021A)
#    (0020,9421) Dimension Description Label         LO: 'Column Position'
#    ---------
# (0020,9311) Dimension Organization Type         CS: 'TILED_FULL'
# (0028,0002) Samples per Pixel                   US: 3
# (0028,0004) Photometric Interpretation          CS: 'YBR_FULL_422'
# (0028,0006) Planar Configuration                US: 0
# (0028,0008) Number of Frames                    IS: '210872'
# (0028,0010) Rows                                US: 256
# (0028,0011) Columns                             US: 256
# (0028,0100) Bits Allocated                      US: 8
# (0028,0101) Bits Stored                         US: 8
# (0028,0102) High Bit                            US: 7
# (0028,0103) Pixel Representation                US: 0
# (0028,0301) Burned In Annotation                CS: 'NO'
# (0028,0302) Recognizable Visual Features        CS: 'NO'
# (0028,2110) Lossy Image Compression             CS: '01'
# (0028,2112) Lossy Image Compression Ratio       DS: '15.586'
# (0028,2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (0040,0512) Container Identifier                LO: '0DLEWX_123831'
# (0040,0513)  Issuer of the Container Identifier Sequence  0 item(s) ----
# (0040,0518)  Container Type Code Sequence  1 item(s) ----
#    (0008,0100) Code Value                          SH: '433466003'
#    (0008,0102) Coding Scheme Designator            SH: 'SCT'
#    (0008,0104) Code Meaning                        LO: 'Microscope slide'
#    ---------
# (0040,0555)  Acquisition Context Sequence  0 item(s) ----
# (0040,0560)  Specimen Description Sequence  2 item(s) ----
#    (0008,2228)  Primary Anatomic Structure Sequence  1 item(s) ----
#       (0008,0100) Code Value                          SH: '40689003'
#       (0008,0102) Coding Scheme Designator            SH: 'SCT'
#       (0008,0104) Code Meaning                        LO: 'Testis'
#       (0008,2230)  Primary Anatomic Structure Modifier Sequence  1 item(s) ----
#          (0008,0100) Code Value                          SH: '108369006'
#          (0008,0102) Coding Scheme Designator            SH: 'SCT'
#          (0008,0104) Code Meaning                        LO: 'Tumor'
#          ---------
#       ---------
#    (0040,0551) Specimen Identifier                 LO: '0DLIF2'
#    (0040,0554) Specimen UID                        UI: 2.25.304190298720350819681389255790523399611
#    (0040,0562)  Issuer of the Specimen Identifier Sequence  0 item(s) ----
#    (0040,0600) Specimen Short Description          LO: 'FFPE HE T'
#    (0040,0610)  Specimen Preparation Sequence  3 item(s) ----
#       (0040,0612)  Specimen Preparation Step Content Item Sequence  3 item(s) ----
#          (0040,A040) Value Type                          CS: 'TEXT'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121041'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Specimen Identifier'
#             ---------
#          (0040,A160) Text Value                          UT: '0DLIF2'
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '111701'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Processing type'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '9265001'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Specimen processing'
#             ---------
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '430864009'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Tissue Fixative'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '431510009'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Formalin'
#             ---------
#          ---------
#       ---------
#       (0040,0612)  Specimen Preparation Step Content Item Sequence  3 item(s) ----
#          (0040,A040) Value Type                          CS: 'TEXT'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121041'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Specimen Identifier'
#             ---------
#          (0040,A160) Text Value                          UT: '0DLIF2'
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '111701'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Processing type'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '9265001'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Specimen processing'
#             ---------
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '430863003'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Embedding medium'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '311731000'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Paraffin wax'
#             ---------
#          ---------
#       ---------
#       (0040,0612)  Specimen Preparation Step Content Item Sequence  4 item(s) ----
#          (0040,A040) Value Type                          CS: 'TEXT'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121041'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Specimen Identifier'
#             ---------
#          (0040,A160) Text Value                          UT: '0DLIF2'
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '111701'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Processing type'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '127790008'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Staining'
#             ---------
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '424361007'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Using substance'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '12710003'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'hematoxylin stain'
#             ---------
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '424361007'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Using substance'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '36879007'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'water soluble eosin stain'
#             ---------
#          ---------
#       ---------
#    ---------
#    (0008,2228)  Primary Anatomic Structure Sequence  1 item(s) ----
#       (0008,0100) Code Value                          SH: '40689003'
#       (0008,0102) Coding Scheme Designator            SH: 'SCT'
#       (0008,0104) Code Meaning                        LO: 'Testis'
#       (0008,2230)  Primary Anatomic Structure Modifier Sequence  1 item(s) ----
#          (0008,0100) Code Value                          SH: '108369006'
#          (0008,0102) Coding Scheme Designator            SH: 'SCT'
#          (0008,0104) Code Meaning                        LO: 'Tumor'
#          ---------
#       ---------
#    (0040,0551) Specimen Identifier                 LO: '0DLIFP'
#    (0040,0554) Specimen UID                        UI: 2.25.242831874863198015387390023169081346127
#    (0040,0562)  Issuer of the Specimen Identifier Sequence  0 item(s) ----
#    (0040,0600) Specimen Short Description          LO: 'FFPE HE T'
#    (0040,0610)  Specimen Preparation Sequence  3 item(s) ----
#       (0040,0612)  Specimen Preparation Step Content Item Sequence  3 item(s) ----
#          (0040,A040) Value Type                          CS: 'TEXT'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121041'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Specimen Identifier'
#             ---------
#          (0040,A160) Text Value                          UT: '0DLIFP'
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '111701'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Processing type'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '9265001'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Specimen processing'
#             ---------
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '430864009'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Tissue Fixative'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '431510009'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Formalin'
#             ---------
#          ---------
#       ---------
#       (0040,0612)  Specimen Preparation Step Content Item Sequence  3 item(s) ----
#          (0040,A040) Value Type                          CS: 'TEXT'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121041'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Specimen Identifier'
#             ---------
#          (0040,A160) Text Value                          UT: '0DLIFP'
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '111701'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Processing type'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '9265001'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Specimen processing'
#             ---------
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '430863003'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Embedding medium'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '311731000'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Paraffin wax'
#             ---------
#          ---------
#       ---------
#       (0040,0612)  Specimen Preparation Step Content Item Sequence  4 item(s) ----
#          (0040,A040) Value Type                          CS: 'TEXT'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121041'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Specimen Identifier'
#             ---------
#          (0040,A160) Text Value                          UT: '0DLIFP'
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '111701'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Processing type'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '127790008'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Staining'
#             ---------
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '424361007'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Using substance'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '12710003'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'hematoxylin stain'
#             ---------
#          ---------
#          (0040,A040) Value Type                          CS: 'CODE'
#          (0040,A043)  Concept Name Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '424361007'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'Using substance'
#             ---------
#          (0040,A168)  Concept Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '36879007'
#             (0008,0102) Coding Scheme Designator            SH: 'SCT'
#             (0008,0104) Code Meaning                        LO: 'water soluble eosin stain'
#             ---------
#          ---------
#       ---------
#    ---------
# (0048,0001) Imaged Volume Width                 FL: 41.3004035949707
# (0048,0002) Imaged Volume Height                FL: 23.17683982849121
# (0048,0003) Imaged Volume Depth                 FL: 0.0
# (0048,0006) Total Pixel Matrix Columns          UL: 156758
# (0048,0007) Total Pixel Matrix Rows             UL: 87969
# (0048,0008)  Total Pixel Matrix Origin Sequence  1 item(s) ----
#    (0040,072A) X Offset in Slide Coordinate System DS: '0'
#    (0040,073A) Y Offset in Slide Coordinate System DS: '0'
#    ---------
# (0048,0010) Specimen Label in Image             CS: 'NO'
# (0048,0011) Focus Method                        CS: 'AUTO'
# (0048,0012) Extended Depth of Field             CS: 'NO'
# (0048,0015) Recommended Absent Pixel CIELab Val US: [65535, 0, 0]
# (0048,0102) Image Orientation (Slide)           DS: [0, -1, 0, -1, 0, 0]
# (0048,0105)  Optical Path Sequence  1 item(s) ----
#    (0022,0016)  Illumination Type Code Sequence  1 item(s) ----
#       (0008,0100) Code Value                          SH: '111744'
#       (0008,0102) Coding Scheme Designator            SH: 'DCM'
#       (0008,0104) Code Meaning                        LO: 'Brightfield illumination'
#       ---------
#    (0028,2000) ICC Profile                         OB: Array of 13113264 elements
#    (0048,0106) Optical Path Identifier             SH: '1'
#    (0048,0108)  Illumination Color Code Sequence  1 item(s) ----
#       (0008,0100) Code Value                          SH: '414298005'
#       (0008,0102) Coding Scheme Designator            SH: 'SCT'
#       (0008,0104) Code Meaning                        LO: 'Full Spectrum'
#       ---------
#    (0048,0112) Objective Lens Power                DS: '40'
#    ---------
# (0048,0302) Number of Optical Paths             UL: 1
# (0048,0303) Total Pixel Matrix Focal Planes     UL: 1
# (5200,9229)  Shared Functional Groups Sequence  1 item(s) ----
#    (0028,9110)  Pixel Measures Sequence  1 item(s) ----
#       (0018,0050) Slice Thickness                     DS: '0'
#       (0028,0030) Pixel Spacing                       DS: [.000263466, .000263466]
#       ---------
#    (0040,0710)  Whole Slide Microscopy Image Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'VOLUME', 'NONE']
#       ---------
#    ---------
# (7FE0,0010) Pixel Data                          OB: Array of 2653092600 elements
# (FFFC,FFFC) Data Set Trailing Padding           OB: Array of 16487532 elements

# %%
# get dictionary of field values
field_values_dict = get_values_dict(dicomFileList)
# Out:
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/b9de96fe-afc1-43a2-9b0e-855233df30cf.dcm processed. 1 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/40a77216-1153-49f6-9a0c-ab542d77b334.dcm processed. 2 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/92297591-f9f7-4271-8adf-5e2b8130fbdd.dcm processed. 3 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/4a4766fa-fcac-4bb1-9d79-7c575efc1988.dcm processed. 4 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/6cb660ed-f540-4322-a13e-9f09322cf51e.dcm processed. 5 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/c317160f-054b-4c92-82ae-86ede93a7c15.dcm processed. 6 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/82a95076-edbd-4671-9fac-da083f34950d.dcm processed. 7 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/ba0d9d33-7b21-4b2a-94d0-4acf55ee3515.dcm processed. 8 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/14250d66-b01d-43b8-941e-36f90a297958.dcm processed. 9 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/0caf4980-781e-430f-a450-9a7be75a1b7f.dcm processed. 10 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/ad10c138-e329-4472-8c38-f5aef22fc841.dcm processed. 11 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/60200624-5f16-4e2a-9759-35ebac229a8e.dcm processed. 12 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/ce4da824-3d49-4bce-bf1f-1f93537503f1.dcm processed. 13 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/92b48db0-65cf-4e3a-8086-9ed31d11f311.dcm processed. 14 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/18b08d15-6b80-45c4-b7b3-12c1d13110ec.dcm processed. 15 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/436d181a-330d-4f60-9e72-c62b166c206e.dcm processed. 16 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/7f54ff7c-8cdd-493e-94a6-1fbbd5efcc99.dcm processed. 17 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/fdfae018-3eed-4aa9-8026-b41a70df7a45.dcm processed. 18 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/cf295d03-6448-46f4-872d-b2be328c9e42.dcm processed. 19 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/e58786a5-c8c0-44ef-9d1c-8eb160770fb9.dcm processed. 20 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/b55c8abc-b719-4320-92d4-2cae6455f6f2.dcm processed. 21 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/38c0cc92-9930-4225-9f0c-6aaac2591aa0.dcm processed. 22 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/63079a05-d1b1-4901-9441-14c2f49de9d3.dcm processed. 23 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/ad74d2fa-1916-4b6f-a3fb-230c2d692cf8.dcm processed. 24 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/8e18d8d3-3018-4482-b61a-0ca986e5f2b4.dcm processed. 25 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/b975e32a-c319-44c2-a31a-cdc0f5e51c8a.dcm processed. 26 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/bb40bfbd-d676-4584-9e35-e3472e45f4a0.dcm processed. 27 files have been read.
# /sbgenomics/project-files/MCI/MCI_Imaging/fa735d8a-ba72-47c0-b3e0-4085c61527dd.dcm processed. 28 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/5728653b-6632-414d-a5ee-3e1a813858cd.dcm processed. 29 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/ae37fb68-cd6c-45e3-bd2b-20f69849525a.dcm processed. 30 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/636730e2-097a-435e-a83e-44b8c139d7af.dcm processed. 31 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging
files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/344b9661-b02b-4e63-8da0-924c41ccc02b.dcm processed. 398 files have been read.
# /sbgenomics/project-files/RMS-Mutation-Prediction/RMS_Imaging/1c1fe331-0d26-455b-88cc-17ad5e691bdc.dcm processed. 399 files have been read.

# %%
len(field_values_dict.keys())
# Out:
# 101

# %%
# print the key, value pair in the field_values dictionary
for key, value in field_values_dict.items():
    print(f"{key}: {len(value)}")
# Out:
# ImageType: 399
# InstanceCreationDate: 399
# InstanceCreationTime: 399
# InstanceCreatorUID: 399
# SOPClassUID: 399
# AcquisitionUID: 399
# SOPInstanceUID: 399
# PyramidUID: 399
# StudyDate: 399
# SeriesDate: 399
# AcquisitionDate: 399
# ContentDate: 399
# AcquisitionDateTime: 399
# StudyTime: 399
# SeriesTime: 399
# AcquisitionTime: 399
# ContentTime: 399
# AccessionNumber: 399
# Modality: 399
# Manufacturer: 399
# ReferringPhysicianName: 399
# TimezoneOffsetFromUTC: 399
# StudyDescription: 399
# SeriesDescription: 399
# AdmittingDiagnosesDescription: 399
# AdmittingDiagnosesCodeSequence:CodeValue: 399
# AdmittingDiagnosesCodeSequence:CodingSchemeDesignator: 399
# AdmittingDiagnosesCodeSequence:CodeMeaning: 399
# ManufacturerModelName: 399
# VolumetricProperties: 399
# PatientName: 399
# PatientID: 399
# PatientBirthDate: 399
# PatientSex: 399
# EthnicGroup: 399
# DeviceSerialNumber: 399
# SoftwareVersions: 399
# ContentQualification: 399
# ContributingEquipmentSequence:Manufacturer: 399
# ContributingEquipmentSequence:InstitutionName: 399
# ContributingEquipmentSequence:InstitutionAddress: 399
# ContributingEquipmentSequence:InstitutionalDepartmentName: 399
# ContributingEquipmentSequence:ManufacturerModelName: 399
# ContributingEquipmentSequence:SoftwareVersions: 399
# ContributingEquipmentSequence:ContributionDateTime: 399
# ContributingEquipmentSequence:ContributionDescription: 399
# PurposeOfReferenceCodeSequence:CodeValue: 399
# PurposeOfReferenceCodeSequence:CodingSchemeDesignator: 399
# PurposeOfReferenceCodeSequence:CodeMeaning: 399
# StudyInstanceUID: 399
# SeriesInstanceUID: 399
# StudyID: 399
# SeriesNumber: 399
# InstanceNumber: 399
# PatientOrientation: 399
# FrameOfReferenceUID: 399
# PositionReferenceIndicator: 399
# ImageComments: 399
# DimensionOrganizationType: 399
# SamplesPerPixel: 399
# PhotometricInterpretation: 399
# PlanarConfiguration: 399
# NumberOfFrames: 399
# Rows: 399
# Columns: 399
# BitsAllocated: 399
# BitsStored: 399
# HighBit: 399
# PixelRepresentation: 399
# BurnedInAnnotation: 399
# RecognizableVisualFeatures: 399
# LossyImageCompression: 399
# ContainerIdentifier: 399
# ContainerTypeCodeSequence:CodeValue: 399
# ContainerTypeCodeSequence:CodingSchemeDesignator: 399
# ContainerTypeCodeSequence:CodeMeaning: 399
# ImagedVolumeWidth: 399
# ImagedVolumeHeight: 399
# ImagedVolumeDepth: 399
# TotalPixelMatrixColumns: 399
# TotalPixelMatrixRows: 399
# TotalPixelMatrixOriginSequence:XOffsetInSlideCoordinateSystem: 399
# TotalPixelMatrixOriginSequence:YOffsetInSlideCoordinateSystem: 399
# SpecimenLabelInImage: 399
# FocusMethod: 399
# ExtendedDepthOfField: 399
# RecommendedAbsentPixelCIELabValue: 399
# ImageOrientationSlide: 399
# IlluminationTypeCodeSequence:CodeValue: 399
# IlluminationTypeCodeSequence:CodingSchemeDesignator: 399
# IlluminationTypeCodeSequence:CodeMeaning: 399
# OpticalPathSequence:OpticalPathIdentifier: 399
# IlluminationColorCodeSequence:CodeValue: 399
# IlluminationColorCodeSequence:CodingSchemeDesignator: 399
# IlluminationColorCodeSequence:CodeMeaning: 399
# OpticalPathSequence:ObjectiveLensPower: 399
# NumberOfOpticalPaths: 399
# TotalPixelMatrixFocalPlanes: 399
# PixelMeasuresSequence:SliceThickness: 399
# PixelMeasuresSequence:PixelSpacing: 399
# WholeSlideMicroscopyImageFrameTypeSequence:FrameType: 399

# %%
# get consistency values dictionary
consistency_values_dict = get_completeness_consistency(field_values_dict)

# %%
# print results by looping through the consistency_values dictionary
for key in consistency_values_dict.keys():
    values = consistency_values_dict[key]
    count = len(values)
    if count > 30: # supress output if the unique counts are greater than 30
        values = "Output supressed"
    print(f"{key} has count of {count}: {values}")
# Out:
# ImageType has count of 399: Output supressed
# InstanceCreationDate has count of 24: Counter({'20240928': 42, '20240927': 41, '20240701': 37, '20230618': 26, '20230603': 26, '20240702': 21, '20230623': 20, '20230613': 19, '20230611': 19, '20230624': 18, '20230616': 14, '20230604': 14, '20230614': 13, '20240926': 12, '20230621': 12, '20230615': 12, '20230607': 7, '20230617': 7, '20230605': 7, '20230608': 7, '20230606': 7, '20230622': 6, '20230609': 6, '20230610': 6})
# InstanceCreationTime has count of 399: Output supressed
# InstanceCreatorUID has count of 1: Counter({'1.3.6.1.4.1.5962.99.3': 399})
# SOPClassUID has count of 1: Counter({'1.2.840.10008.5.1.4.1.1.77.1.6': 399})
# AcquisitionUID has count of 68: Output supressed
# SOPInstanceUID has count of 399: Output supressed
# PyramidUID has count of 69: Output supressed
# StudyDate has count of 32: Output supressed
# SeriesDate has count of 33: Output supressed
# AcquisitionDate has count of 33: Output supressed
# ContentDate has count of 33: Output supressed
# AcquisitionDateTime has count of 65: Output supressed
# StudyTime has count of 63: Output supressed
# SeriesTime has count of 65: Output supressed
# AcquisitionTime has count of 65: Output supressed
# ContentTime has count of 65: Output supressed
# AccessionNumber has count of 62: Output supressed
# Modality has count of 1: Counter({'SM': 399})
# Manufacturer has count of 1: Counter({'Leica Biosystems': 399})
# ReferringPhysicianName has count of 1: Counter({'^^^^': 399})
# TimezoneOffsetFromUTC has count of 1: Counter({'+0000': 399})
# StudyDescription has count of 1: Counter({'Histopathology': 399})
# SeriesDescription has count of 3: Counter({'FFPE HE': 246, 'FFPE HE T': 123, 'OCT HE T': 30})
# AdmittingDiagnosesDescription has count of 2: Counter({'Rhabdomyosarcoma': 246, 'Not Present': 153})
# AdmittingDiagnosesCodeSequence:CodeValue has count of 4: Counter({'302847003': 246, '8910/3': 82, '8900/3': 50, '8920/3': 21})
# AdmittingDiagnosesCodeSequence:CodingSchemeDesignator has count of 2: Counter({'SCT': 246, 'ICDO3': 153})
# AdmittingDiagnosesCodeSequence:CodeMeaning has count of 4: Counter({'Rhabdomyosarcoma': 246, 'Embryonal rhabdomyosarcoma, NOS': 82, 'Rhabdomyosarcoma, NOS': 50, 'Alveolar rhabdomyosarcoma': 21})
# ManufacturerModelName has count of 1: Counter({'Aperio converted by com.pixelmed.convert.TIFFToDicom': 399})
# VolumetricProperties has count of 1: Counter({'VOLUME': 399})
# PatientName has count of 62: Output supressed
# PatientID has count of 62: Output supressed
# PatientBirthDate has count of 1: Counter({'': 399})
# PatientSex has count of 2: Counter({'F': 224, 'M': 175})
# EthnicGroup has count of 5: Counter({'White': 256, 'Black': 61, 'Not Present': 51, 'Asian': 22, 'Mx Hisp White': 9})
# DeviceSerialNumber has count of 3: Counter({'SS7168CNTLR': 246, 'SS12035': 79, 'SS12172': 74})
# SoftwareVersions has count of 399: Output supressed
# ContentQualification has count of 1: Counter({'RESEARCH': 399})
# ContributingEquipmentSequence:Manufacturer has count of 1: Counter({'PixelMed': 399})
# ContributingEquipmentSequence:InstitutionName has count of 1: Counter({'PixelMed': 399})
# ContributingEquipmentSequence:InstitutionAddress has count of 1: Counter({'Bangor, PA': 399})
# ContributingEquipmentSequence:InstitutionalDepartmentName has count of 1: Counter({'Software Development': 399})
# ContributingEquipmentSequence:ManufacturerModelName has count of 1: Counter({'com.pixelmed.convert.TIFFToDicom': 399})
# ContributingEquipmentSequence:SoftwareVersions has count of 3: Counter({'Vers. Sun Dec 25 16:38:31 EST 2022': 246, 'Vers. Thu Sep 26 15:45:33 EDT 2024': 95, 'Vers. Sat May  4 08:37:59 EDT 2024': 58})
# ContributingEquipmentSequence:ContributionDateTime has count of 399: Output supressed
# ContributingEquipmentSequence:ContributionDescription has count of 1: Counter({'TIFF to DICOM conversion': 399})
# PurposeOfReferenceCodeSequence:CodeValue has count of 1: Counter({'109103': 399})
# PurposeOfReferenceCodeSequence:CodingSchemeDesignator has count of 1: Counter({'DCM': 399})
# PurposeOfReferenceCodeSequence:CodeMeaning has count of 1: Counter({'Modifying Equipment': 399})
# StudyInstanceUID has count of 63: Output supressed
# SeriesInstanceUID has count of 68: Output supressed
# StudyID has count of 62: Output supressed
# SeriesNumber has count of 1: Counter({'1': 399})
# InstanceNumber has count of 7: Counter({'4': 68, '3': 68, '2': 68, '1': 68, '5': 58, '6': 47, '7': 22})
# PatientOrientation has count of 1: Counter({'': 399})
# FrameOfReferenceUID has count of 86: Output supressed
# PositionReferenceIndicator has count of 2: Counter({'SLIDE_CORNER': 341, 'UNKNOWN': 58})
# ImageComments has count of 311: Output supressed
# DimensionOrganizationType has count of 1: Counter({'TILED_FULL': 399})
# SamplesPerPixel has count of 1: Counter({3: 399})
# PhotometricInterpretation has count of 3: Counter({'RGB': 153, 'YBR_FULL_422': 135, 'YBR_RCT': 111})
# PlanarConfiguration has count of 1: Counter({0: 399})
# NumberOfFrames has count of 194: Output supressed
# Rows has count of 45: Output supressed
# Columns has count of 39: Output supressed
# BitsAllocated has count of 1: Counter({8: 399})
# BitsStored has count of 1: Counter({8: 399})
# HighBit has count of 1: Counter({7: 399})
# PixelRepresentation has count of 1: Counter({0: 399})
# BurnedInAnnotation has count of 1: Counter({'NO': 399})
# RecognizableVisualFeatures has count of 1: Counter({'NO': 399})
# LossyImageCompression has count of 2: Counter({'00': 205, '01': 194})
# ContainerIdentifier has count of 65: Output supressed
# ContainerTypeCodeSequence:CodeValue has count of 1: Counter({'433466003': 399})
# ContainerTypeCodeSequence:CodingSchemeDesignator has count of 1: Counter({'SCT': 399})
# ContainerTypeCodeSequence:CodeMeaning has count of 1: Counter({'Microscope slide': 399})
# ImagedVolumeWidth has count of 167: Output supressed
# ImagedVolumeHeight has count of 286: Output supressed
# ImagedVolumeDepth has count of 2: Counter({0.0: 305, 'Not Present': 94})
# TotalPixelMatrixColumns has count of 223: Output supressed
# TotalPixelMatrixRows has count of 259: Output supressed
# TotalPixelMatrixOriginSequence:XOffsetInSlideCoordinateSystem has count of 58: Output supressed
# TotalPixelMatrixOriginSequence:YOffsetInSlideCoordinateSystem has count of 55: Output supressed
# SpecimenLabelInImage has count of 2: Counter({'NO': 305, 'YES': 94})
# FocusMethod has count of 1: Counter({'AUTO': 399})
# ExtendedDepthOfField has count of 1: Counter({'NO': 399})
# RecommendedAbsentPixelCIELabValue has count of 399: Output supressed
# ImageOrientationSlide has count of 399: Output supressed
# IlluminationTypeCodeSequence:CodeValue has count of 1: Counter({'111744': 399})
# IlluminationTypeCodeSequence:CodingSchemeDesignator has count of 1: Counter({'DCM': 399})
# IlluminationTypeCodeSequence:CodeMeaning has count of 1: Counter({'Brightfield illumination': 399})
# OpticalPathSequence:OpticalPathIdentifier has count of 1: Counter({'1': 399})
# IlluminationColorCodeSequence:CodeValue has count of 1: Counter({'414298005': 399})
# IlluminationColorCodeSequence:CodingSchemeDesignator has count of 1: Counter({'SCT': 399})
# IlluminationColorCodeSequence:CodeMeaning has count of 1: Counter({'Full Spectrum': 399})
# OpticalPathSequence:ObjectiveLensPower has count of 1: Counter({'40': 399})
# NumberOfOpticalPaths has count of 1: Counter({1: 399})
# TotalPixelMatrixFocalPlanes has count of 1: Counter({1: 399})
# PixelMeasuresSequence:SliceThickness has count of 2: Counter({'0': 305, 'Not Present': 94})
# PixelMeasuresSequence:PixelSpacing has count of 399: Output supressed
# WholeSlideMicroscopyImageFrameTypeSequence:FrameType has count of 399: Output supressed

# %%
# pd.set_option('display.max_columns', None)

# %%
# dicom_df = pd.DataFrame(field_values_dict)

# %%
# dicom_df.to_csv("/sbgenomics/output-files/dicom_metadata_extract.csv", index=False)

# %% [markdown]
# # Final Completeness, Consistency, Outlier, and Imbalance calculations

# %%
# initiate counters
missing_count = 0
values_dict = field_values_dict.copy()
numeric_fields_list = []
outlier_count = 0

# %%
# loop through all keys in the consistency values dictionary
for key in consistency_values_dict.keys():
        values = consistency_values_dict[key]

        #print results
        if type(values) != list and len(values)<30: 
            print(f"{key} has count of {len(values)}: {values}")
        else: 
            print(f"{key} has count of {len(values)}")
        
        # get missing and outlier counts
        try:
            # get missing counts
            missing_count = missing_count + consistency_values_dict[key]["Not Present"] # count number of "Not Present"
            missing_count = missing_count + consistency_values_dict[key][""] # count number of empty string

            # get outlier counts

            # remove "Not present" for outlier calculation
            if "Not present" in values: 
                values_dict[key] = values_dict[key].remove("Not Present")

            # remove empty string for outlier calculation
            if "" in values: 
                values_dict[key] = values_dict[key].remove("")

            # field is numeric    
            if all(isinstance(value, int) for value in values_dict[key]) or all(isinstance(value, float) for value in values_dict[key]):
                numeric_fields_list.append(key) # add key to numeric_fields list

                values_dict[key] = values_dict[key].sort() # sort the values
                values_array = np.array(values_dict[key]) # turn type into an array
                first_quantile = np.quantile(values_array, 0.25) # get first quantile
                third_quantile = np.quantile(values_array, 0.75) # get third quantile
                IQR = third_quantile - first_quantile # get interquantile range
                
                # get list of outliers under the first quantile
                if any(v < (first_quantile - IQR) for v in values_dict[key]):
                    outlier_list = [v for v in values_dict[key] if v < (first_quantile - IQR)]
                    print(f"low outliers: {outlier_list}")
                    outlier_count = outlier_count + len(outlier_list)

                # get list of outliers over the third quantile
                if any(v > (third_quantile + IQR) for v in values_dict[key]):
                    outlier_list = [v for v in values_dict[key] if v > (third_quantile + IQR)]
                    print(f"high outliers: {outlier_list}")
                    outlier_count = outlier_count + len(outlier_list)

        except Exception as e: # handle exception
            continue

print(f"Number of missing values: {missing_count}")
# Out:
# ImageType has count of 399
# InstanceCreationDate has count of 24: Counter({'20240928': 42, '20240927': 41, '20240701': 37, '20230618': 26, '20230603': 26, '20240702': 21, '20230623': 20, '20230613': 19, '20230611': 19, '20230624': 18, '20230616': 14, '20230604': 14, '20230614': 13, '20240926': 12, '20230621': 12, '20230615': 12, '20230607': 7, '20230617': 7, '20230605': 7, '20230608': 7, '20230606': 7, '20230622': 6, '20230609': 6, '20230610': 6})
# InstanceCreationTime has count of 399
# InstanceCreatorUID has count of 1: Counter({'1.3.6.1.4.1.5962.99.3': 399})
# SOPClassUID has count of 1: Counter({'1.2.840.10008.5.1.4.1.1.77.1.6': 399})
# AcquisitionUID has count of 68
# SOPInstanceUID has count of 399
# PyramidUID has count of 69
# StudyDate has count of 32
# SeriesDate has count of 33
# AcquisitionDate has count of 33
# ContentDate has count of 33
# AcquisitionDateTime has count of 65
# StudyTime has count of 63
# SeriesTime has count of 65
# AcquisitionTime has count of 65
# ContentTime has count of 65
# AccessionNumber has count of 62
# Modality has count of 1: Counter({'SM': 399})
# Manufacturer has count of 1: Counter({'Leica Biosystems': 399})
# ReferringPhysicianName has count of 1: Counter({'^^^^': 399})
# TimezoneOffsetFromUTC has count of 1: Counter({'+0000': 399})
# StudyDescription has count of 1: Counter({'Histopathology': 399})
# SeriesDescription has count of 3: Counter({'FFPE HE': 246, 'FFPE HE T': 123, 'OCT HE T': 30})
# AdmittingDiagnosesDescription has count of 2: Counter({'Rhabdomyosarcoma': 246, 'Not Present': 153})
# AdmittingDiagnosesCodeSequence:CodeValue has count of 4: Counter({'302847003': 246, '8910/3': 82, '8900/3': 50, '8920/3': 21})
# AdmittingDiagnosesCodeSequence:CodingSchemeDesignator has count of 2: Counter({'SCT': 246, 'ICDO3': 153})
# AdmittingDiagnosesCodeSequence:CodeMeaning has count of 4: Counter({'Rhabdomyosarcoma': 246, 'Embryonal rhabdomyosarcoma, NOS': 82, 'Rhabdomyosarcoma, NOS': 50, 'Alveolar rhabdomyosarcoma': 21})
# ManufacturerModelName has count of 1: Counter({'Aperio converted by com.pixelmed.convert.TIFFToDicom': 399})
# VolumetricProperties has count of 1: Counter({'VOLUME': 399})
# PatientName has count of 62
# PatientID has count of 62
# PatientBirthDate has count of 1: Counter({'': 399})
# PatientSex has count of 2: Counter({'F': 224, 'M': 175})
# EthnicGroup has count of 5: Counter({'White': 256, 'Black': 61, 'Not Present': 51, 'Asian': 22, 'Mx Hisp White': 9})
# DeviceSerialNumber has count of 3: Counter({'SS7168CNTLR': 246, 'SS12035': 79, 'SS12172': 74})
# SoftwareVersions has count of 399
# ContentQualification has count of 1: Counter({'RESEARCH': 399})
# ContributingEquipmentSequence:Manufacturer has count of 1: Counter({'PixelMed': 399})
# ContributingEquipmentSequence:InstitutionName has count of 1: Counter({'PixelMed': 399})
# ContributingEquipmentSequence:InstitutionAddress has count of 1: Counter({'Bangor, PA': 399})
# ContributingEquipmentSequence:InstitutionalDepartmentName has count of 1: Counter({'Software Development': 399})
# ContributingEquipmentSequence:ManufacturerModelName has count of 1: Counter({'com.pixelmed.convert.TIFFToDicom': 399})
# ContributingEquipmentSequence:SoftwareVersions has count of 3: Counter({'Vers. Sun Dec 25 16:38:31 EST 2022': 246, 'Vers. Thu Sep 26 15:45:33 EDT 2024': 95, 'Vers. Sat May  4 08:37:59 EDT 2024': 58})
# ContributingEquipmentSequence:ContributionDateTime has count of 399
# ContributingEquipmentSequence:ContributionDescription has count of 1: Counter({'TIFF to DICOM conversion': 399})
# PurposeOfReferenceCodeSequence:CodeValue has count of 1: Counter({'109103': 399})
# PurposeOfReferenceCodeSequence:CodingSchemeDesignator has count of 1: Counter({'DCM': 399})
# PurposeOfReferenceCodeSequence:CodeMeaning has count of 1: Counter({'Modifying Equipment': 399})
# StudyInstanceUID has count of 63
# SeriesInstanceUID has count of 68
# StudyID has count of 62
# SeriesNumber has count of 1: Counter({'1': 399})
# InstanceNumber has count of 7: Counter({'4': 68, '3': 68, '2': 68, '1': 68, '5': 58, '6': 47, '7': 22})
# PatientOrientation has count of 1: Counter({'': 399})
# FrameOfReferenceUID has count of 86
# PositionReferenceIndicator has count of 2: Counter({'SLIDE_CORNER': 341, 'UNKNOWN': 58})
# ImageComments has count of 311
# DimensionOrganizationType has count of 1: Counter({'TILED_FULL': 399})
# SamplesPerPixel has count of 1: Counter({3: 399})
# PhotometricInterpretation has count of 3: Counter({'RGB': 153, 'YBR_FULL_422': 135, 'YBR_RCT': 111})
# PlanarConfiguration has count of 1: Counter({0: 399})
# NumberOfFrames has count of 194
# Rows has count of 45
# Columns has count of 39
# BitsAllocated has count of 1: Counter({8: 399})
# BitsStored has count of 1: Counter({8: 399})
# HighBit has count of 1: Counter({7: 399})
# PixelRepresentation has count of 1: Counter({0: 399})
# BurnedInAnnotation has count of 1: Counter({'NO': 399})
# RecognizableVisualFeatures has count of 1: Counter({'NO': 399})
# LossyImageCompression has count of 2: Counter({'00': 205, '01': 194})
# ContainerIdentifier has count of 65
# ContainerTypeCodeSequence:CodeValue has count of 1: Counter({'433466003': 399})
# ContainerTypeCodeSequence:CodingSchemeDesignator has count of 1: Counter({'SCT': 399})
# ContainerTypeCodeSequence:CodeMeaning has count of 1: Counter({'Microscope slide': 399})
# ImagedVolumeWidth has count of 167
# ImagedVolumeHeight has count of 286
# ImagedVolumeDepth has count of 2: Counter({0.0: 305, 'Not Present': 94})
# TotalPixelMatrixColumns has count of 223
# TotalPixelMatrixRows has count of 259
# TotalPixelMatrixOriginSequence:XOffsetInSlideCoordinateSystem has count of 58
# TotalPixelMatrixOriginSequence:YOffsetInSlideCoordinateSystem has count of 55
# SpecimenLabelInImage has count of 2: Counter({'NO': 305, 'YES': 94})
# FocusMethod has count of 1: Counter({'AUTO': 399})
# ExtendedDepthOfField has count of 1: Counter({'NO': 399})
# RecommendedAbsentPixelCIELabValue has count of 399
# ImageOrientationSlide has count of 399
# IlluminationTypeCodeSequence:CodeValue has count of 1: Counter({'111744': 399})
# IlluminationTypeCodeSequence:CodingSchemeDesignator has count of 1: Counter({'DCM': 399})
# IlluminationTypeCodeSequence:CodeMeaning has count of 1: Counter({'Brightfield illumination': 399})
# OpticalPathSequence:OpticalPathIdentifier has count of 1: Counter({'1': 399})
# IlluminationColorCodeSequence:CodeValue has count of 1: Counter({'414298005': 399})
# IlluminationColorCodeSequence:CodingSchemeDesignator has count of 1: Counter({'SCT': 399})
# IlluminationColorCodeSequence:CodeMeaning has count of 1: Counter({'Full Spectrum': 399})
# OpticalPathSequence:ObjectiveLensPower has count of 1: Counter({'40': 399})
# NumberOfOpticalPaths has count of 1: Counter({1: 399})
# TotalPixelMatrixFocalPlanes has count of 1: Counter({1: 399})
# PixelMeasuresSequence:SliceThickness has count of 2: Counter({'0': 305, 'Not Present': 94})
# PixelMeasuresSequence:PixelSpacing has count of 399
# WholeSlideMicroscopyImageFrameTypeSequence:FrameType has count of 399
# Number of missing values: 1302

# %%
# percentage missing
missing_count/(len(values_dict.keys())*399) * 100
# Out:
# 3.2308494007295465

# %%
# percentage outliers
outlier_count/(len(numeric_fields_list)*399) * 100
# Out:
# 0.0

# %%
# numeric fields list
numeric_fields_list
# Out:
# ['SeriesNumber',
#  'InstanceNumber',
#  'SamplesPerPixel',
#  'PlanarConfiguration',
#  'NumberOfFrames',
#  'Rows',
#  'Columns',
#  'BitsAllocated',
#  'BitsStored',
#  'HighBit',
#  'PixelRepresentation',
#  'TotalPixelMatrixColumns',
#  'TotalPixelMatrixRows',
#  'TotalPixelMatrixOriginSequence:XOffsetInSlideCoordinateSystem',
#  'TotalPixelMatrixOriginSequence:YOffsetInSlideCoordinateSystem',
#  'OpticalPathSequence:ObjectiveLensPower',
#  'NumberOfOpticalPaths',
#  'TotalPixelMatrixFocalPlanes']
